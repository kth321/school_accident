# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/공모전/23 학교데이터경진대회/data
# Out:
# /content/drive/MyDrive/공모전/23 학교데이터경진대회/data

# %%
import pandas as pd

# %%
table_20 = pd.read_excel('/content/drive/MyDrive/공모전/23 학교데이터경진대회/data/1. (raw) 사고 발생 데이터_수정.xlsx',
                         sheet_name='2020(수정)',
                         engine='openpyxl')

table_21 = pd.read_excel('/content/drive/MyDrive/공모전/23 학교데이터경진대회/data/1. (raw) 사고 발생 데이터_수정.xlsx',
                         sheet_name='2021(수정)',
                         engine='openpyxl')

table_22 = pd.read_excel('/content/drive/MyDrive/공모전/23 학교데이터경진대회/data/1. (raw) 사고 발생 데이터_수정.xlsx',
                         sheet_name='2022(수정)',
                         engine='openpyxl')

# %%
table_20
# Out:
#              구분     학교명  지역      교육청 설립유형 학교급 사고자구분 사고자성별 사고자학년       사고접수일  \
# 0      A0000001  치악초등학교  강원  원주교육지원청   공립   초  일반학생     여   5학년  2020-01-10
# 1      A0000002  정선초등학교  강원  정선교육지원청   공립   초  일반학생     여   6학년  2020-01-22
# 2      A0000003  정선초등학교  강원  정선교육지원청   공립   초  일반학생     남   4학년  2020-01-22
# 3      A0000004  태장초등학교  강원  원주교육지원청   공립   초  일반학생     남   6학년  2020-06-19
# 4      A0000005   버들중학교  강원  원주교육지원청   공립   중  일반학생     여   2학년  2020-02-07
# ...         ...     ...  ..      ...  ...  ..   ...   ...   ...         ...
# 41935  A0041936   영동중학교  충북  영동교육지원청   공립   중  일반학생     여   3학년  2020-12-30
# 41936  A0041937  오송고등학교  충북  충청북도교육청   공립   고  일반학생     남   2학년  2020-12-31
# 41937  A0041938  세명고등학교  충북  충청북도교육청   사립   고  일반학생     남   2학년  2020-12-30
# 41938  A0041939   산남중학교  충북  청주교육지원청   공립   중  일반학생     남   1학년  2020-12-31
# 41939  A0041940  진흥초등학교  충북  청주교육지원청   공립   초  일반학생     남   2학년  2020-12-31
#
# ...
